# %%
from scipy.io import loadmat

# %%
data = loadmat('Synthetic_1.mat')

# %%
gtLabel = data['L']

# %%
X = data['Y']

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Mon Jan  2 01:19:36 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Y': array([[-0.08842569, -0.01859932,  0.01022569, ..., -0.02310527,
#           0.0235342 , -0.02613335],
#         [-0.0174303 ,  0.00229955,  0.00933987, ...,  0.04139996,
#          -0.08174692, -0.00428669],
#         [ 0.01841379, -0.01545102,  0.06493916, ...,  0.00150502,
#          -0.01347295,  0.01599202],
#         ...,
#         [-0.01165246, -0.02826263,  0.01446044, ..., -0.00888784,
#          -0.02333152, -0.0691406 ],
#         [ 0.03715653, -0.04776915, -0.05751748, ..., -0.03727774,
#           0.00770057,  0.02242581],
#         [-0.02093584,  0.00562446,  0.00854736, ...,  0.00424613,
#          -0.00079292,  0.00540915]]),
#  'L': array([[ 300,  700, 1200, 1500, 1900, 2200, 2400, 2700, 2900]])}

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X[:, 1])
